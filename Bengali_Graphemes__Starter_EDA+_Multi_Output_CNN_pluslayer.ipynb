# %% [markdown]
# <a href="https://colab.research.google.com/github/Tatsuya50/DeepLearningStudy/blob/master/Bengali_Graphemes__Starter_EDA%2B_Multi_Output_CNN_pluslayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kaggleからのデータダウンロード
# ＊理由は不明だがたまにjsonファイルは取り直さないと認証が取れなくなる現象がある模様

# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
#      <input type="file" id="files-1eb94528-b86f-4ffb-b13b-06051497f2f8" name="files[]" multiple disabled />
#      <output id="result-1eb94528-b86f-4ffb-b13b-06051497f2f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (2).json
# {'kaggle.json': b'{"username":"tatsuya214355","key":"8db2ef1ba9a1e08be854e5642d946d75"}'}

# %%
# !mkdir -p ~/.kaggle  #kaggleのファイルを作る
# !cp kaggle.json ~/.kaggle  #kaggleのトークンをコピーする

from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth

auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])

filename = "/root/.kaggle/kaggle.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Download 100%.

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c bengaliai-cv19
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# train_image_data_1.parquet.zip: Skipping, found more recently modified local copy (use --force to force download)
# test_image_data_1.parquet.zip: Skipping, found more recently modified local copy (use --force to force download)
# train_image_data_2.parquet.zip: Skipping, found more recently modified local copy (use --force to force download)
# test_image_data_0.parquet.zip: Skipping, found more recently modified local copy (use --force to force download)
# test.csv: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# test_image_data_2.parquet.zip: Skipping, found more recently modified local copy (use --force to force download)
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# class_map.csv: Skipping, found more recently modified local copy (use --force to force download)
# train_image_data_0.parquet.zip: Skipping, found more recently modified local copy (use --force to force download)
# train_image_data_3.parquet.zip: Skipping, found more recently modified local copy (use --force to force download)
# test_image_data_3.parquet.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from zipfile import ZipFile
file_name = 'train.csv.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')

from zipfile import ZipFile
file_name = 'test_image_data_0.parquet.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')


from zipfile import ZipFile
file_name = 'test_image_data_1.parquet.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')


from zipfile import ZipFile
file_name = 'test_image_data_2.parquet.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')


from zipfile import ZipFile
file_name = 'test_image_data_3.parquet.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')


from zipfile import ZipFile
file_name = 'train_image_data_0.parquet.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')


from zipfile import ZipFile
file_name = 'train_image_data_1.parquet.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')

from zipfile import ZipFile
file_name = 'train_image_data_2.parquet.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')
from zipfile import ZipFile
file_name = 'train_image_data_3.parquet.zip'#ここに解凍したいファイルの名前を入れてください。

with ZipFile(file_name , 'r') as zip_file:
  zip_file.extractall()
  print('done')
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done

# %% [markdown]
# # ライブラリの導入

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import datetime
import pytz

start_time = datetime.datetime.now(pytz.timezone('Asia/Tokyo'))
print(start_time)
# Any results you write to the current directory are saved as output.
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# 2020-01-31 14:09:06.084490+09:00

# %% [markdown]
# # inputデータの導入

# %%
train_df_ = pd.read_csv('train.csv')
test_df_ = pd.read_csv('test.csv')
class_map_df = pd.read_csv('class_map.csv')
sample_sub_df = pd.read_csv('sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# ## Exploratory Data Analysis
# Exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.

# %% [markdown]
# # EDA

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    #myfont = ImageFont.truetype('/kaggle/input/kalpurush-fonts/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %% [markdown]
# ### Number of unique values

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %% [markdown]
# ### Most used top 10 Grapheme Roots in training set

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %% [markdown]
# ### Top 5 Consonant Diacritic in training data

# %%
top_5_consonants = get_n(train_df_, 'consonant_diacritic', 5)
top_5_consonants
# Out:
#    index component   count
# 0    179         0  125278
# 2    181        র্   23465
# 5    184        ্র   21397
# 4    183        ্য   21270
# 1    180         ঁ    7424

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),interpolation=cv2.INTER_AREA)
            #gaussian_3 = cv2.GaussianBlur(image, (9,9), 10.0) #unblur
            #image = cv2.addWeighted(image, 1.5, gaussian_3, -0.5, 0, image)
            #kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]]) #filter
            #image = cv2.filter2D(image, -1, kernel)
            #ret,image = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
            resized[df.index[i]] = image.reshape(-1)
    else:
        for i in range(df.shape[0]):
            image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),interpolation=cv2.INTER_AREA)
            #gaussian_3 = cv2.GaussianBlur(image, (9,9), 10.0) #unblur
            #image = cv2.addWeighted(image, 1.5, gaussian_3, -0.5, 0, image)
            #kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]]) #filter
            #image = cv2.filter2D(image, -1, kernel)
            #ret,image = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
            resized[df.index[i]] = image.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ## Basic Model

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
#model = Dropout(rate=0.2)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
#model = Dropout(rate=0.2)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.2)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
#model = Dropout(rate=0.2)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.2)(model)


model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)


model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 64, 64, 32)   320         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 64, 64, 32)   128         conv2d_111[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 32, 32, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 32, 32, 32)   25632       max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 32, 32, 64)   18496       conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 32, 32, 64)   36928       conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 32, 32, 64)   256         conv2d_115[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 16, 16, 64)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 16, 16, 64)   102464      max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 64)   256         conv2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 16, 16, 64)   36928       batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 16, 16, 64)   256         conv2d_119[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 8, 8, 64)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 8, 8, 64)     102464      max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 64)     256         conv2d_120[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 64)     0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 8, 8, 128)    73856       dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 8, 8, 128)    147584      conv2d_121[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 8, 8, 128)    147584      conv2d_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 128)    512         conv2d_123[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 4, 4, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 4, 4, 128)    409728      max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 4, 4, 128)    512         conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 4, 4, 128)    147584      batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 4, 4, 128)    147584      conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 4, 4, 128)    147584      conv2d_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 4, 4, 128)    512         conv2d_127[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 2, 2, 128)    0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 2, 2, 128)    409728      max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 2, 2, 128)    512         conv2d_128[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 2, 2, 128)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 2, 2, 256)    295168      dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 2, 2, 256)    590080      conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 2, 2, 256)    590080      conv2d_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 2, 2, 256)    1024        conv2d_131[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 1, 1, 256)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 1, 1, 256)    1638656     max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 1, 1, 256)    1024        conv2d_132[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 1, 1, 256)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           dropout_11[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         263168      flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 6,086,362
# Trainable params: 6,083,738
# Non-trainable params: 2,624
# __________________________________________________________________________________________________

# %% [markdown]
# Let's visualize the 3-tailed (3 output) CNN by plotting it.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.000001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.000001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.000001)

# %%
batch_size = 256
epochs = 10

# %% [markdown]
# # データの拡張

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %% [markdown]
# ### Training loop
# Dense3のaccだけ他と比較しても低くなる傾向アリ。
# この層だけの改善ができないか考える余地あり
# 但しエポックを増やすことでだいぶ改善される模様
# 現時点ではエポック10で実行しているのでエポックを増やすことで改善が見込める。
# 但しかなりの時間がかかるので実行時間制限に引っかからないかは注意が必要かも

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(f'train_image_data_{i}.parquet'), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    aug_ratio = 3

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=(x_train.shape[0] // batch_size) * aug_ratio, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/10
# 540/540 [==============================] - 78s 144ms/step - loss: 6.5934 - dense_3_loss: 4.4344 - dense_4_loss: 1.1141 - dense_5_loss: 1.0448 - dense_3_acc: 0.0430 - dense_4_acc: 0.6051 - dense_5_acc: 0.6472 - val_loss: 5.2470 - val_dense_3_loss: 3.9575 - val_dense_4_loss: 0.5465 - val_dense_5_loss: 0.7429 - val_dense_3_acc: 0.0667 - val_dense_4_acc: 0.8111 - val_dense_5_acc: 0.7394
# Epoch 2/10
#   1/540 [..............................] - ETA: 1:01 - loss: 5.3551 - dense_3_loss: 3.9662 - dense_4_loss: 0.5826 - dense_5_loss: 0.8063 - dense_3_acc: 0.0625 - dense_4_acc: 0.8164 - dense_5_acc: 0.6992
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1379: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_3_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1379: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_4_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1379: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 540/540 [==============================] - 64s 118ms/step - loss: 4.7518 - dense_3_loss: 3.6280 - dense_4_loss: 0.5277 - dense_5_loss: 0.5961 - dense_3_acc: 0.0951 - dense_4_acc: 0.8295 - dense_5_acc: 0.7862 - val_loss: 3.8263 - val_dense_3_loss: 3.0702 - val_dense_4_loss: 0.3672 - val_dense_5_loss: 0.3890 - val_dense_3_acc: 0.1660 - val_dense_4_acc: 0.8805 - val_dense_5_acc: 0.8701
# Epoch 3/10
# 540/540 [==============================] - 63s 118ms/step - loss: 3.9138 - dense_3_loss: 3.0541 - dense_4_loss: 0.4492 - dense_5_loss: 0.4105 - dense_3_acc: 0.1620 - dense_4_acc: 0.8606 - dense_5_acc: 0.8653 - val_loss: 3.5556 - val_dense_3_loss: 2.7818 - val_dense_4_loss: 0.4712 - val_dense_5_loss: 0.3026 - val_dense_3_acc: 0.2148 - val_dense_4_acc: 0.8561 - val_dense_5_acc: 0.9064
# Epoch 4/10
# 540/540 [==============================] - 63s 117ms/step - loss: 3.4467 - dense_3_loss: 2.7027 - dense_4_loss: 0.3988 - dense_5_loss: 0.3452 - dense_3_acc: 0.2193 - dense_4_acc: 0.8795 - dense_5_acc: 0.8932 - val_loss: 2.7645 - val_dense_3_loss: 2.2769 - val_dense_4_loss: 0.2603 - val_dense_5_loss: 0.2273 - val_dense_3_acc: 0.3057 - val_dense_4_acc: 0.9233 - val_dense_5_acc: 0.9328
# Epoch 5/10
# 540/540 [==============================] - 63s 117ms/step - loss: 3.1358 - dense_3_loss: 2.4504 - dense_4_loss: 0.3729 - dense_5_loss: 0.3124 - dense_3_acc: 0.2715 - dense_4_acc: 0.8901 - dense_5_acc: 0.9071 - val_loss: 2.6278 - val_dense_3_loss: 2.1272 - val_dense_4_loss: 0.2800 - val_dense_5_loss: 0.2205 - val_dense_3_acc: 0.3465 - val_dense_4_acc: 0.9213 - val_dense_5_acc: 0.9370
# Epoch 6/10
# 540/540 [==============================] - 63s 118ms/step - loss: 2.9318 - dense_3_loss: 2.2825 - dense_4_loss: 0.3530 - dense_5_loss: 0.2963 - dense_3_acc: 0.3138 - dense_4_acc: 0.8981 - dense_5_acc: 0.9129 - val_loss: 2.3817 - val_dense_3_loss: 1.9167 - val_dense_4_loss: 0.2412 - val_dense_5_loss: 0.2238 - val_dense_3_acc: 0.4075 - val_dense_4_acc: 0.9313 - val_dense_5_acc: 0.9360
# Epoch 7/10
# 540/540 [==============================] - 63s 117ms/step - loss: 2.6900 - dense_3_loss: 2.0922 - dense_4_loss: 0.3262 - dense_5_loss: 0.2717 - dense_3_acc: 0.3573 - dense_4_acc: 0.9096 - dense_5_acc: 0.9210 - val_loss: 2.0836 - val_dense_3_loss: 1.6729 - val_dense_4_loss: 0.2259 - val_dense_5_loss: 0.1848 - val_dense_3_acc: 0.4707 - val_dense_4_acc: 0.9400 - val_dense_5_acc: 0.9457
# Epoch 8/10
# 540/540 [==============================] - 63s 117ms/step - loss: 2.4583 - dense_3_loss: 1.9092 - dense_4_loss: 0.2961 - dense_5_loss: 0.2530 - dense_3_acc: 0.4060 - dense_4_acc: 0.9169 - dense_5_acc: 0.9276 - val_loss: 1.8997 - val_dense_3_loss: 1.5454 - val_dense_4_loss: 0.1915 - val_dense_5_loss: 0.1629 - val_dense_3_acc: 0.5118 - val_dense_4_acc: 0.9477 - val_dense_5_acc: 0.9529
# Epoch 9/10
# 540/540 [==============================] - 63s 117ms/step - loss: 2.1421 - dense_3_loss: 1.6706 - dense_4_loss: 0.2480 - dense_5_loss: 0.2235 - dense_3_acc: 0.4702 - dense_4_acc: 0.9286 - dense_5_acc: 0.9358 - val_loss: 1.6757 - val_dense_3_loss: 1.3241 - val_dense_4_loss: 0.2005 - val_dense_5_loss: 0.1511 - val_dense_3_acc: 0.5900 - val_dense_4_acc: 0.9475 - val_dense_5_acc: 0.9572
# Epoch 10/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.9233 - dense_3_loss: 1.4901 - dense_4_loss: 0.2276 - dense_5_loss: 0.2056 - dense_3_acc: 0.5219 - dense_4_acc: 0.9342 - dense_5_acc: 0.9404 - val_loss: 1.4192 - val_dense_3_loss: 1.1441 - val_dense_4_loss: 0.1434 - val_dense_5_loss: 0.1317 - val_dense_3_acc: 0.6535 - val_dense_4_acc: 0.9602 - val_dense_5_acc: 0.9656
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/10
# 540/540 [==============================] - 64s 118ms/step - loss: 1.9458 - dense_3_loss: 1.4764 - dense_4_loss: 0.2458 - dense_5_loss: 0.2237 - dense_3_acc: 0.5427 - dense_4_acc: 0.9319 - dense_5_acc: 0.9366 - val_loss: 1.4184 - val_dense_3_loss: 1.1108 - val_dense_4_loss: 0.1528 - val_dense_5_loss: 0.1549 - val_dense_3_acc: 0.6637 - val_dense_4_acc: 0.9644 - val_dense_5_acc: 0.9612
# Epoch 2/10
# 540/540 [==============================] - 63s 118ms/step - loss: 1.7346 - dense_3_loss: 1.3014 - dense_4_loss: 0.2255 - dense_5_loss: 0.2077 - dense_3_acc: 0.5948 - dense_4_acc: 0.9386 - dense_5_acc: 0.9417 - val_loss: 1.4209 - val_dense_3_loss: 1.1042 - val_dense_4_loss: 0.1618 - val_dense_5_loss: 0.1548 - val_dense_3_acc: 0.6652 - val_dense_4_acc: 0.9604 - val_dense_5_acc: 0.9562
# Epoch 3/10
# 540/540 [==============================] - 63s 118ms/step - loss: 1.5806 - dense_3_loss: 1.1751 - dense_4_loss: 0.2111 - dense_5_loss: 0.1944 - dense_3_acc: 0.6350 - dense_4_acc: 0.9435 - dense_5_acc: 0.9464 - val_loss: 1.1213 - val_dense_3_loss: 0.8573 - val_dense_4_loss: 0.1320 - val_dense_5_loss: 0.1320 - val_dense_3_acc: 0.7486 - val_dense_4_acc: 0.9679 - val_dense_5_acc: 0.9661
# Epoch 4/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.4717 - dense_3_loss: 1.0817 - dense_4_loss: 0.2041 - dense_5_loss: 0.1859 - dense_3_acc: 0.6677 - dense_4_acc: 0.9453 - dense_5_acc: 0.9484 - val_loss: 1.2519 - val_dense_3_loss: 0.9508 - val_dense_4_loss: 0.1611 - val_dense_5_loss: 0.1400 - val_dense_3_acc: 0.7207 - val_dense_4_acc: 0.9599 - val_dense_5_acc: 0.9642
# Epoch 5/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.4013 - dense_3_loss: 1.0214 - dense_4_loss: 0.1988 - dense_5_loss: 0.1812 - dense_3_acc: 0.6891 - dense_4_acc: 0.9478 - dense_5_acc: 0.9505 - val_loss: 1.0894 - val_dense_3_loss: 0.8069 - val_dense_4_loss: 0.1549 - val_dense_5_loss: 0.1276 - val_dense_3_acc: 0.7727 - val_dense_4_acc: 0.9634 - val_dense_5_acc: 0.9691
# Epoch 6/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.3440 - dense_3_loss: 0.9699 - dense_4_loss: 0.1965 - dense_5_loss: 0.1776 - dense_3_acc: 0.7066 - dense_4_acc: 0.9490 - dense_5_acc: 0.9516 - val_loss: 1.0541 - val_dense_3_loss: 0.7728 - val_dense_4_loss: 0.1616 - val_dense_5_loss: 0.1197 - val_dense_3_acc: 0.7822 - val_dense_4_acc: 0.9624 - val_dense_5_acc: 0.9716
# Epoch 7/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.3045 - dense_3_loss: 0.9247 - dense_4_loss: 0.2074 - dense_5_loss: 0.1725 - dense_3_acc: 0.7216 - dense_4_acc: 0.9467 - dense_5_acc: 0.9538 - val_loss: 1.0159 - val_dense_3_loss: 0.7492 - val_dense_4_loss: 0.1326 - val_dense_5_loss: 0.1342 - val_dense_3_acc: 0.7991 - val_dense_4_acc: 0.9691 - val_dense_5_acc: 0.9689
# Epoch 8/10
# 540/540 [==============================] - 63s 118ms/step - loss: 1.1511 - dense_3_loss: 0.8221 - dense_4_loss: 0.1705 - dense_5_loss: 0.1585 - dense_3_acc: 0.7527 - dense_4_acc: 0.9569 - dense_5_acc: 0.9579 - val_loss: 1.0999 - val_dense_3_loss: 0.7778 - val_dense_4_loss: 0.1766 - val_dense_5_loss: 0.1455 - val_dense_3_acc: 0.7969 - val_dense_4_acc: 0.9632 - val_dense_5_acc: 0.9654
# Epoch 9/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.1354 - dense_3_loss: 0.8031 - dense_4_loss: 0.1741 - dense_5_loss: 0.1581 - dense_3_acc: 0.7616 - dense_4_acc: 0.9565 - dense_5_acc: 0.9578 - val_loss: 0.9412 - val_dense_3_loss: 0.6797 - val_dense_4_loss: 0.1385 - val_dense_5_loss: 0.1231 - val_dense_3_acc: 0.8233 - val_dense_4_acc: 0.9686 - val_dense_5_acc: 0.9706
# Epoch 10/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.0906 - dense_3_loss: 0.7665 - dense_4_loss: 0.1716 - dense_5_loss: 0.1525 - dense_3_acc: 0.7712 - dense_4_acc: 0.9575 - dense_5_acc: 0.9596 - val_loss: 0.9387 - val_dense_3_loss: 0.6595 - val_dense_4_loss: 0.1694 - val_dense_5_loss: 0.1098 - val_dense_3_acc: 0.8340 - val_dense_4_acc: 0.9622 - val_dense_5_acc: 0.9751
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/10
# 540/540 [==============================] - 64s 118ms/step - loss: 1.3142 - dense_3_loss: 0.9227 - dense_4_loss: 0.2065 - dense_5_loss: 0.1849 - dense_3_acc: 0.7447 - dense_4_acc: 0.9492 - dense_5_acc: 0.9513 - val_loss: 0.9471 - val_dense_3_loss: 0.6689 - val_dense_4_loss: 0.1413 - val_dense_5_loss: 0.1369 - val_dense_3_acc: 0.8277 - val_dense_4_acc: 0.9704 - val_dense_5_acc: 0.9637
# Epoch 2/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.1895 - dense_3_loss: 0.8299 - dense_4_loss: 0.1879 - dense_5_loss: 0.1716 - dense_3_acc: 0.7644 - dense_4_acc: 0.9544 - dense_5_acc: 0.9547 - val_loss: 0.8452 - val_dense_3_loss: 0.6134 - val_dense_4_loss: 0.1158 - val_dense_5_loss: 0.1161 - val_dense_3_acc: 0.8422 - val_dense_4_acc: 0.9761 - val_dense_5_acc: 0.9706
# Epoch 3/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.0711 - dense_3_loss: 0.7457 - dense_4_loss: 0.1689 - dense_5_loss: 0.1565 - dense_3_acc: 0.7896 - dense_4_acc: 0.9588 - dense_5_acc: 0.9595 - val_loss: 0.8335 - val_dense_3_loss: 0.5886 - val_dense_4_loss: 0.1226 - val_dense_5_loss: 0.1224 - val_dense_3_acc: 0.8526 - val_dense_4_acc: 0.9754 - val_dense_5_acc: 0.9694
# Epoch 4/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.0656 - dense_3_loss: 0.7318 - dense_4_loss: 0.1757 - dense_5_loss: 0.1580 - dense_3_acc: 0.7931 - dense_4_acc: 0.9579 - dense_5_acc: 0.9588 - val_loss: 0.8245 - val_dense_3_loss: 0.5837 - val_dense_4_loss: 0.1126 - val_dense_5_loss: 0.1282 - val_dense_3_acc: 0.8541 - val_dense_4_acc: 0.9768 - val_dense_5_acc: 0.9696
# Epoch 5/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.9996 - dense_3_loss: 0.6843 - dense_4_loss: 0.1675 - dense_5_loss: 0.1478 - dense_3_acc: 0.8051 - dense_4_acc: 0.9603 - dense_5_acc: 0.9620 - val_loss: 0.8083 - val_dense_3_loss: 0.5738 - val_dense_4_loss: 0.1181 - val_dense_5_loss: 0.1163 - val_dense_3_acc: 0.8571 - val_dense_4_acc: 0.9719 - val_dense_5_acc: 0.9706
# Epoch 6/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.9919 - dense_3_loss: 0.6755 - dense_4_loss: 0.1655 - dense_5_loss: 0.1509 - dense_3_acc: 0.8096 - dense_4_acc: 0.9609 - dense_5_acc: 0.9610 - val_loss: 0.7761 - val_dense_3_loss: 0.5378 - val_dense_4_loss: 0.1222 - val_dense_5_loss: 0.1161 - val_dense_3_acc: 0.8698 - val_dense_4_acc: 0.9739 - val_dense_5_acc: 0.9716
# Epoch 7/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.9374 - dense_3_loss: 0.6399 - dense_4_loss: 0.1553 - dense_5_loss: 0.1422 - dense_3_acc: 0.8199 - dense_4_acc: 0.9635 - dense_5_acc: 0.9633 - val_loss: 0.8143 - val_dense_3_loss: 0.5681 - val_dense_4_loss: 0.1201 - val_dense_5_loss: 0.1261 - val_dense_3_acc: 0.8521 - val_dense_4_acc: 0.9729 - val_dense_5_acc: 0.9666
# Epoch 8/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.9283 - dense_3_loss: 0.6245 - dense_4_loss: 0.1590 - dense_5_loss: 0.1447 - dense_3_acc: 0.8248 - dense_4_acc: 0.9624 - dense_5_acc: 0.9624 - val_loss: 0.8053 - val_dense_3_loss: 0.5697 - val_dense_4_loss: 0.1098 - val_dense_5_loss: 0.1259 - val_dense_3_acc: 0.8636 - val_dense_4_acc: 0.9766 - val_dense_5_acc: 0.9721
# Epoch 9/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.8906 - dense_3_loss: 0.5977 - dense_4_loss: 0.1523 - dense_5_loss: 0.1406 - dense_3_acc: 0.8336 - dense_4_acc: 0.9639 - dense_5_acc: 0.9642 - val_loss: 0.8226 - val_dense_3_loss: 0.5708 - val_dense_4_loss: 0.1283 - val_dense_5_loss: 0.1235 - val_dense_3_acc: 0.8668 - val_dense_4_acc: 0.9739 - val_dense_5_acc: 0.9694
# Epoch 10/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.8451 - dense_3_loss: 0.5688 - dense_4_loss: 0.1418 - dense_5_loss: 0.1346 - dense_3_acc: 0.8411 - dense_4_acc: 0.9670 - dense_5_acc: 0.9654 - val_loss: 0.7883 - val_dense_3_loss: 0.5376 - val_dense_4_loss: 0.1315 - val_dense_5_loss: 0.1192 - val_dense_3_acc: 0.8750 - val_dense_4_acc: 0.9729 - val_dense_5_acc: 0.9731
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/10
# 540/540 [==============================] - 64s 118ms/step - loss: 1.1085 - dense_3_loss: 0.7528 - dense_4_loss: 0.1936 - dense_5_loss: 0.1622 - dense_3_acc: 0.8063 - dense_4_acc: 0.9547 - dense_5_acc: 0.9585 - val_loss: 1.0714 - val_dense_3_loss: 0.6830 - val_dense_4_loss: 0.2736 - val_dense_5_loss: 0.1148 - val_dense_3_acc: 0.8327 - val_dense_4_acc: 0.9417 - val_dense_5_acc: 0.9719
# Epoch 2/10
# 540/540 [==============================] - 63s 117ms/step - loss: 1.0233 - dense_3_loss: 0.6892 - dense_4_loss: 0.1742 - dense_5_loss: 0.1599 - dense_3_acc: 0.8176 - dense_4_acc: 0.9595 - dense_5_acc: 0.9587 - val_loss: 0.8998 - val_dense_3_loss: 0.6185 - val_dense_4_loss: 0.1466 - val_dense_5_loss: 0.1346 - val_dense_3_acc: 0.8429 - val_dense_4_acc: 0.9676 - val_dense_5_acc: 0.9666
# Epoch 3/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.9506 - dense_3_loss: 0.6365 - dense_4_loss: 0.1647 - dense_5_loss: 0.1493 - dense_3_acc: 0.8290 - dense_4_acc: 0.9616 - dense_5_acc: 0.9620 - val_loss: 0.7514 - val_dense_3_loss: 0.5292 - val_dense_4_loss: 0.1236 - val_dense_5_loss: 0.0987 - val_dense_3_acc: 0.8720 - val_dense_4_acc: 0.9768 - val_dense_5_acc: 0.9756
# Epoch 4/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.8805 - dense_3_loss: 0.5870 - dense_4_loss: 0.1530 - dense_5_loss: 0.1404 - dense_3_acc: 0.8413 - dense_4_acc: 0.9640 - dense_5_acc: 0.9640 - val_loss: 0.6812 - val_dense_3_loss: 0.4740 - val_dense_4_loss: 0.1224 - val_dense_5_loss: 0.0848 - val_dense_3_acc: 0.8882 - val_dense_4_acc: 0.9778 - val_dense_5_acc: 0.9821
# Epoch 5/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.8257 - dense_3_loss: 0.5483 - dense_4_loss: 0.1446 - dense_5_loss: 0.1328 - dense_3_acc: 0.8511 - dense_4_acc: 0.9664 - dense_5_acc: 0.9661 - val_loss: 0.7029 - val_dense_3_loss: 0.4833 - val_dense_4_loss: 0.1357 - val_dense_5_loss: 0.0839 - val_dense_3_acc: 0.8810 - val_dense_4_acc: 0.9726 - val_dense_5_acc: 0.9803
# Epoch 6/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.8427 - dense_3_loss: 0.5559 - dense_4_loss: 0.1532 - dense_5_loss: 0.1336 - dense_3_acc: 0.8513 - dense_4_acc: 0.9643 - dense_5_acc: 0.9661 - val_loss: 0.7079 - val_dense_3_loss: 0.4972 - val_dense_4_loss: 0.1239 - val_dense_5_loss: 0.0869 - val_dense_3_acc: 0.8783 - val_dense_4_acc: 0.9773 - val_dense_5_acc: 0.9801
# Epoch 7/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.7811 - dense_3_loss: 0.5146 - dense_4_loss: 0.1413 - dense_5_loss: 0.1252 - dense_3_acc: 0.8623 - dense_4_acc: 0.9679 - dense_5_acc: 0.9687 - val_loss: 1.3653 - val_dense_3_loss: 0.9188 - val_dense_4_loss: 0.3063 - val_dense_5_loss: 0.1402 - val_dense_3_acc: 0.7989 - val_dense_4_acc: 0.9370 - val_dense_5_acc: 0.9642
# Epoch 8/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.8265 - dense_3_loss: 0.5444 - dense_4_loss: 0.1528 - dense_5_loss: 0.1293 - dense_3_acc: 0.8526 - dense_4_acc: 0.9655 - dense_5_acc: 0.9669 - val_loss: 0.7614 - val_dense_3_loss: 0.5338 - val_dense_4_loss: 0.1287 - val_dense_5_loss: 0.0988 - val_dense_3_acc: 0.8681 - val_dense_4_acc: 0.9766 - val_dense_5_acc: 0.9768
# Epoch 9/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.7579 - dense_3_loss: 0.4954 - dense_4_loss: 0.1386 - dense_5_loss: 0.1239 - dense_3_acc: 0.8660 - dense_4_acc: 0.9687 - dense_5_acc: 0.9684 - val_loss: 0.7650 - val_dense_3_loss: 0.5298 - val_dense_4_loss: 0.1384 - val_dense_5_loss: 0.0967 - val_dense_3_acc: 0.8832 - val_dense_4_acc: 0.9724 - val_dense_5_acc: 0.9791
# Epoch 10/10
# 540/540 [==============================] - 63s 117ms/step - loss: 0.7172 - dense_3_loss: 0.4664 - dense_4_loss: 0.1354 - dense_5_loss: 0.1153 - dense_3_acc: 0.8742 - dense_4_acc: 0.9689 - dense_5_acc: 0.9709 - val_loss: 0.6991 - val_dense_3_loss: 0.5010 - val_dense_4_loss: 0.1097 - val_dense_5_loss: 0.0884 - val_dense_3_acc: 0.8907 - val_dense_4_acc: 0.9793 - val_dense_5_acc: 0.9808

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
end_time = datetime.datetime.now(pytz.timezone('Asia/Tokyo'))
print("\nStart   Time  : " + str(start_time))
print(  "End     Time  : " + str(end_time))
print(  "Elapsed Time  : " + str(end_time - start_time))
# Out:
# Start   Time  : 2020-01-31 14:09:06.084490+09:00
# End     Time  : 2020-01-31 15:17:47.864295+09:00
# Elapsed Time  : 1:08:41.779805

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    #plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet('/kaggle/input/bengaliai-cv19/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
